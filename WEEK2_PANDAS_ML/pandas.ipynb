# %%
# Out:
# Running cells with 'Python 3.13.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/PMLS/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Panadas tasks

# %%
import pandas as pd

# %%
data = {
    'Name': ['Ali', 'Sara', 'Ahmed', 'Ayesha'],
    'Age': [25, 30, 22, 28],
    'City': ['Lahore', 'Karachi', 'Islamabad', 'Peshawar'],
    'Salary': [50000, 80000, 45000, 70000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age       City  Salary
# 0     Ali   25     Lahore   50000
# 1    Sara   30    Karachi   80000
# 2   Ahmed   22  Islamabad   45000
# 3  Ayesha   28   Peshawar   70000

# %%
# Pehli 5 rows dekho
df.head()
# Out:
#      Name  Age       City  Salary
# 0     Ali   25     Lahore   50000
# 1    Sara   30    Karachi   80000
# 2   Ahmed   22  Islamabad   45000
# 3  Ayesha   28   Peshawar   70000

# %%
# Data ki info dekho
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
#  3   Salary  4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
# Missing values dekho
df.isnull().sum()
# Out:
# Name      0
# Age       0
# City      0
# Salary    0
# dtype: int64

# %%
# Kaggle se koi bhi CSV utha ke try karo
# df2 = pd.read_csv(r"C:\Users\PMLS\OneDrive\Desktop\Dl_python\Week2-Pandas-ML\kainat.csv")
# df2.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Kaggle se koi bhi CSV utha ke try karo
# ----> 2 df2 = pd.read_csv(r"C:\Users\PMLS\OneDrive\Desktop\Dl_python\Week2-Pandas-ML\kainat.csv")
#       3 df2.head()
#
# ...
