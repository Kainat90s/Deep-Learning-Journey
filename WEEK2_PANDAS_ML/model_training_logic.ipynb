# %% [markdown]
# Training Logics

# %%
import torch
import torch.nn as nn

# Simple model banao
model = nn.Linear(2, 1)  # 2 inputs, 1 output

# Input data
x = torch.tensor([[1.0, 2.0]])

# Forward pass
output = model(x)
print(output)
# Out:
# tensor([[-1.4223]], grad_fn=<AddmmBackward0>)
